# %% [markdown]
# ## Setup

# %%
import os

# The Google Cloud Notebook product has specific requirements
#IS_GOOGLE_CLOUD_NOTEBOOK = os.path.exists("/opt/deeplearning/metadata/env_version")

# Google Cloud Notebook requires dependencies to be installed with '--user'
USER_FLAG = "--user"
UPGRADE_FLAG = "--upgrade"
#if IS_GOOGLE_CLOUD_NOTEBOOK:
#    USER_FLAG = "--user"

# %%
#!pip3 install {USER_FLAG} {UPGRADE_FLAG} tensorflow==2.7
# !pip3 install {USER_FLAG} {UPGRADE_FLAG} tensorflow==2.7.1
# !pip3 install {USER_FLAG} {UPGRADE_FLAG} tensorflow-data-validation==1.6.0
# !pip3 install {USER_FLAG} {UPGRADE_FLAG} tensorflow-model-analysis==0.37.0
# !pip3 install {USER_FLAG} {UPGRADE_FLAG} tensorflow-transform==1.6.0
# !pip3 install {USER_FLAG} {UPGRADE_FLAG} tfx==1.6.1
#!pip3 install {USER_FLAG} {UPGRADE_FLAG} kfp==1.8.5
# !pip3 install {USER_FLAG} {UPGRADE_FLAG} kfp==1.8.11
# !pip3 install {USER_FLAG} {UPGRADE_FLAG} google-cloud-aiplatform==1.11.0
# Out:
# ...
#   Using cached tensorflow-2.7.1-cp37-cp37m-manylinux2010_x86_64.whl (495.0 MB)
# ...
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
#   WARNING: The scripts estimator_ckpt_converter, import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# ...
# ...
#   Using cached kfp-1.8.11-py3-none-any.whl
# ...
#   Attempting uninstall: kfp
#     Found existing installation: kfp 1.8.5
#     Uninstalling kfp-1.8.5:
#       Successfully uninstalled kfp-1.8.5
#   WARNING: The scripts dsl-compile, dsl-compile-v2 and kfp are installed in '/home/jupyter/.local/bin' which is not on PATH.
# ...

# %%
# !pip install {USER_FLAG} {UPGRADE_FLAG} -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 297 kB 5.2 MB/s
# ...
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.0.1
#     Uninstalling pytest-7.0.1:
#       Successfully uninstalled pytest-7.0.1
#   WARNING: The scripts py.test and pytest are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
