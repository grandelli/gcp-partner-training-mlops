# %% [markdown]
# ## Setup

# %%
import os

USER_FLAG = "--user"
UPGRADE_FLAG = "--upgrade"
QUIET_FLAG = "--quiet"

# %% [markdown]
# **Heads-up:** do not change the current package versions or you will face problems. Ignore all the reported dependency errors.

# %%
# !pip install {USER_FLAG} tfx==1.2.0
# Out:
# ...
#   Using cached tfx-1.2.0-py3-none-any.whl (2.4 MB)
# ...
#   Using cached ml_pipelines_sdk-1.2.0-py3-none-any.whl (1.2 MB)
# ...
#   Attempting uninstall: ml-pipelines-sdk
#     Found existing installation: ml-pipelines-sdk 1.2.1
#     Uninstalling ml-pipelines-sdk-1.2.1:
#       Successfully uninstalled ml-pipelines-sdk-1.2.1
#   Attempting uninstall: tfx
#     Found existing installation: tfx 1.2.1
#     Uninstalling tfx-1.2.1:
#       Successfully uninstalled tfx-1.2.1
#   WARNING: The script tfx is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# !pip install {USER_FLAG} -r requirements.txt
# Out:
# ...
#   Using cached google_cloud_bigquery-2.26.0-py2.py3-none-any.whl (201 kB)
# ...
#   Using cached google_cloud_aiplatform-1.4.3-py2.py3-none-any.whl (1.4 MB)
# ...
#   Using cached google_cloud_pubsub-2.1.0-py2.py3-none-any.whl (177 kB)
# ...
#   Using cached grpcio-1.44.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# ...
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 2.20.0
#     Uninstalling google-cloud-bigquery-2.20.0:
#       Successfully uninstalled google-cloud-bigquery-2.20.0
#   Attempting uninstall: google-cloud-pubsub
#     Found existing installation: google-cloud-pubsub 1.7.0
#     Uninstalling google-cloud-pubsub-1.7.0:
#       Successfully uninstalled google-cloud-pubsub-1.7.0
#   Attempting uninstall: google-cloud-aiplatform
# ...
